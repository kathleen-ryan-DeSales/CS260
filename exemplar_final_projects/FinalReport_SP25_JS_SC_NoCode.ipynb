# %%
#code for imports - removed by Dr. R

# %% [markdown]
# ---
# #### CS 260 Database and Data Visualization - Final Project - SP25
# ---
#
# # Trash Talk: Analyzing Baltimore Harbor's Waste

# %% [markdown]
# ### By: Joshua Sites and Steven Counterman

# %% [markdown]
# ---
#
# ## 1. Introduction

# %% [markdown]
# The Waterfront Partnership of Baltimore launched the Healthy Harbor Initiative to help clean up the city’s waterways in an attempt to make them more enjoyable for both residents and visitors. The program focuses on restoration, education, and community involvement to improve water quality and increase public awareness of waterway pollution.
#
# As part of that effort, Mr. Trash Wheel was installed in 2014 at the mouth of the Jones Falls River. Over the years, the project expanded with the addition of three more trash wheels: Professor Trash Wheel in 2016, Captain Trash Wheel in 2018, and Gwynnda the Good Wheel of the West in 2021. These devices are both functional and engaging, as they draw attention through their quirky names and designs.
#
# This report looks at data collected from all four trash wheels across several years. The dataset includes information about the contents of each dumpster, the amount and type of garbage collected, and when the collection happened. We also used local traffic volume data to see if there is any connection between how busy the area is and how much trash ends up in the water.
#
# Our analysis shows that the total amount of garbage collected has gone up over time, especially after each new trash wheel was installed. There is a noticeable spike in 2021 after Gwynnda was deployed. That does not necessarily mean pollution got worse. It could also mean the project is doing a better job at catching trash before it spreads.
#
# A strong link between traffic volume and trash collected was found. Busier roads might be leading to more litter, which ends up in the harbor. Even though cigarette butts were the most common item found, we focused on plastic bottles in our analysis because they are widely known to cause long-term environmental problems. Bottle collection rates varied across the different wheels, giving us a look at how trash types differ by location. We also saw a connection between the number of wrappers and plastic bags, which could mean that some people are tossing full bags of trash into the water rather than individual pieces.

# %% [markdown]
# ---
#
# ## 2. Data

# %% [markdown]
# A direct link to the data can be found at the following website.
#  * https://github.com/SC4214/trashwheel
#
# Mr. Trash Wheel, Professor Trash Wheel, Captain Trash Wheel, and Gwynnda the Good Wheel of the West are all located within the Baltimore Harbor area in Baltimore, Maryland USA. Mister Trash Wheel is located at the Jones Falls River mouth. Professor Trash Wheel is located at Harris Creek. Captain Trash Wheel is located at Masonville Cove Environmental Education Center. Gwynnda Trash Wheel is located at Ridgely's Cove at the mouth of the Gwynns Falls.
#
# Since the inception of Mister Trash Wheel in May 2014, each dumpster load is either hand-counted or calculated with random samples per paddle. If crew members are present, they manually count the number of each type of trash listed on a single conveyor paddle. This process is repeated several times during the filling of a dumpster. An average is then calculated for each item per paddle. The average is then multiplied by the paddle rate and the time it takes to fill the dumpster. The dumpsters are counted at least once per year by volunteers and are otherwise calculated by random batch samples. The process is explained next.
#
# Sometimes, volunteers hand-count the entire dumpster, though this cannot always be done due to the lengthy workload involved. If no crew is present, nor are there any volunteers, random bushel-sized samples are taken of the collected material. These samples are collected and multiplied by 325, as there are 325 bushels in a typical dumpster load. Professor Trash Wheel was introduced in December 2016, Captain Trash Wheel in June 2018, and Gwynnda Trash Wheel in June 2021. Their data in the CSV file reflects this accordingly.

# %%
#Code to set up DB removed by Dr. R

# %%
#Code to select from the trashwheel table removed by Dr. R
# Out:
#        title           wheel_name  dumpster_num     month  year        date  \
# 0     mister   Mister Trash Wheel             1       May  2014   5/16/2014
# 1     mister   Mister Trash Wheel             2       May  2014   5/16/2014
# 2     mister   Mister Trash Wheel             3       May  2014   5/16/2014
# 3     mister   Mister Trash Wheel             4       May  2014   5/17/2014
# 4     mister   Mister Trash Wheel             5       May  2014   5/17/2014
# ..       ...                  ...           ...       ...   ...         ...
# 988  gwynnda  Gwynnda Trash Wheel           216  December  2023  12/27/2023
# 989  gwynnda  Gwynnda Trash Wheel           217  December  2023  12/27/2023
# 990  gwynnda  Gwynnda Trash Wheel           218  December  2023  12/28/2023
# 991  gwynnda  Gwynnda Trash Wheel           219  December  2023  12/29/2023
# 992  gwynnda  Gwynnda Trash Wheel           220  December  2023  12/29/2023
#
# ...

# %% [markdown]
# ### 2.1 Summary of Variables within the Trashwheel Table

# %% [markdown]
# The trashwheel table has 16 columns/variables and 993 rows.  All variables are explained in this section.
#
# Note that the table was read in from a csv, but had we created a formal SQLite database for the table, the schema would have been as follows.
#
# ```
# CREATE TABLE "trashwheel" (
# 	"title"	TEXT,
# 	"wheel_name"	TEXT,
# 	"dumpster_num"	INTEGER,
# 	"month"	TEXT,
# 	"year"	INTEGER,
# 	"date"	TEXT,
# 	"weight_tons"	REAL,
# 	"volume_cubic_yds"	REAL,
# 	"num_bottles_plastic"	INTEGER,
# 	"num_polystyrene"	INTEGER,
# 	"num_cig_butts"	INTEGER,
# 	"num_bottles_glass"	INTEGER,
# 	"num_plastic_bags"	INTEGER,
# 	"num_wrappers"	INTEGER,
# 	"num_sports_balls"	INTEGER,
# 	"num_homes_powered"	INTEGER,
# 	PRIMARY KEY("dumpster_num","wheel_name")
# );
# ```
#
# Here are the variables, their descriptions, their units, their types, and some descriptive statistics.
#
# **CATEGORICAL VARIABLES**
#
# * **title** - This column contains the prefix of the name of the dumpster
#     * Number of missing values: 0
#     * Contains 4 distinct values:
#         * mister - refers to Mister Trash Wheel
#         * professor - refers to Professor Trash Wheel
#         * captain - refers to Captain Trash Wheel
#         * gwynnda - refers to Gwynnda Trash Wheel
#     * This column was included with the raw data and does not serve a purpose for this project.
#
# * **wheel_name** – This column contains the name of the trash wheel the dumpster was collected from.
#     * Number of missing values: 0
#     * Contains 4 distinct values:
#         * Mister Trash Wheel - The trash interceptor located at the Jones Falls River mouth in Baltimore, Maryland.
#         * Professor Trash Wheel - The trash interceptor located at Harris Creek in Baltimore, Maryland.
#         * Captain Trash Wheel - The trash interceptor located at Masonville Cove Environmental Education Center in Baltimore, Maryland.
#         * Gwynnda Trash Wheel - The trash interceptor located at Ridgely's Cove at the mouth of the Gwynns Falls in Baltimore, Maryland.
#     * All trash wheels are located within the Baltimore harbor.
#
# * **date** - This column contains the date the dumpster was collected.
#     * Number of missing values: 0
#     * Contains 519 distinct values:
#         * Examples:
#             * 5/16/2014
#             * 12/29/2023
#         * These values represent the date the dumpster was collected.
#     * The dates are in MM/DD/YYYY format.
#
# * **month** - This column contains the month when the dumpster was collected.
#     * Number of missing values: 0
#     * Contains 12 distinct values:
#         * January
#         * February
#         * March
#         * April
#         * May
#         * June
#         * July
#         * August
#         * September
#         * October
#         * November
#         * December
#
# **QUANTITATIVE DISCRETE VARIABLES**
#
# * **year** – This column contains the year the dumpster was collected.
#     * Number of missing values: 0
#     * Contains 10 distinct values:
#         * 2014
#         * 2015
#         * 2016
#         * 2017
#         * 2018
#         * 2019
#         * 2020
#         * 2021
#         * 2022
#         * 2023
#     * Professor Trash Wheel was not implemented until 2017, Captain Trash Wheel in 2018, and Gwynnda Trash Wheel in 2021.
#
# * **dumpster_num** – This column contains the dumpster number for each trash wheel, starting from 1 and increasing independently.
#     * Number of missing values: 0
#     * max value: 629
#     * min value: 1
#     * Mister Trash Wheel has significantly more dumpsters filled as it has run longer than the others. This significantly skews the average number of dumpsters.
#
# * **num_bottles_plastic** – This column contains the number of plastic bottles in the relevant dumpster load.
#     * Number of missing values: 1
#     * Units: bottles
#     * max value: 0
#     * min value: 9,830
#     * average value: 2,219
#
# * **num_polystyrene** – This column contains the number of polystyrene objects in the relevant dumpster load.
#     * Number of missing values: 1
#     * Units: pieces
#     * max value: 0
#     * min value: 11,528
#     * average value: 1,437
#
# * **num_cig_butts** – This column contains the number of cigarette butts in the relevant dumpster load.
#     * Number of missing values: 1
#     * Units: butts
#     * max value: 310,000
#     * min value: 0
#     * average value: 13,728
#
# * **num_bottles_glass** – This column contains the number of glass bottles in the relevant dumpster load.
#     * Number of missing values: 251
#     * Units: bottles
#     * max value: 110
#     * min value: 0
#     * average value: 21
#
# * **num_plastic_bags** – This column contains the number of plastic bags in the relevant dumpster load.
#     * Number of missing values: 1
#     * Units: bags
#     * max value: 13,450
#     * min value: 0
#     * average value: 984
#
# * **num_wrappers** – This column contains the number of wrappers in the relevant dumpster load.
#     * Number of missing values: 144
#     * Units: wrappers
#     * max value: 20,100
#     * min value: 0
#     * average value: 2,239
#
# * **num_sports_balls** – This column contains the number of sports balls in the relevant dumpster load.
#     * Number of missing values: 364
#     * Units: balls
#     * max value: 56
#     * min value: 0
#     * average value: 14
#
# * **num_homes_powered** – This column contains the number of homes powered by the incineration of the relevant dumpster load. (Each ton of trash generates approximately 500 kilowatts of energy and a home uses 30 kilowatts of energy per day on average.)
#     * Number of missing values: 0
#     * Units: homes
#     * max value: 94
#     * min value: 0
#     * average value: 46
#
# **QUANTITATIVE CONTINUOUS VARIABLES**
#
# * **weight_tons** – This column contains the weight of the dumpster load in tons.
#     * Number of missing values: 0
#     * Units: tons
#     * max value: 5.62
#     * min value: 0.61
#     * average value: 2.966
#
# * **volume_cubic_yds** – This column contains the volume of the dumpster load in cubic yards.
#     * Number of missing values: 0
#     * Units: cubic yards
#     * max value: 20
#     * min value: 5
#     * average value: 14.919

# %% [markdown]
# ### 2.2 Code Used to Summarize Variables

# %% [markdown]
# In this section we include the code used to describe the variables in the previous section.

# %%
#Get the number of null/missing values in each categorical column - Code removed by Dr. R
# Out:
#    num_missing_title  num_missing_wheel_name  num_missing_dumpster_num  \
# 0                  0                       0                         0
#
#    num_missing_month  num_missing_year  num_missing_date
# 0                  0                 0                 0

# %%
#Get the distinct values in the wheel_name column -  Code removed by Dr. R
# Out:
#               wheel_name
# 0     Mister Trash Wheel
# 1  Professor Trash Wheel
# 2    Captain Trash Wheel
# 3    Gwynnda Trash Wheel

# %%
#Get the distinct values in the date column -  Code removed by Dr. R
# Out:
#            date
# 0     5/16/2014
# 1     5/17/2014
# 2     5/20/2014
# 3     5/21/2014
# 4     5/28/2014
# ..          ...
# 514  12/22/2023
# 515  12/26/2023
# 516  12/27/2023
# 517  12/28/2023
# 518  12/29/2023
#
# [519 rows x 1 columns]

# %%
#Get the distinct values in the month column -  Code removed by Dr. R
# Out:
#         month
# 0         May
# 1        June
# 2        July
# 3      August
# 4   September
# 5     October
# 6    November
# 7    December
# 8     January
# 9    February
# 10      March
# 11      April

# %%
#Get the distinct values in the year column
# Out:
#    year
# 0  2014
# 1  2015
# 2  2016
# 3  2017
# 4  2018
# 5  2019
# 6  2020
# 7  2021
# 8  2022
# 9  2023

# %%
#Get the min, max, and number of missing values in the
#dumpster_num column - code removed by Dr. R
# Out:
#    MIN(dumpster_num)  MAX(dumpster_num)  num_missing
# 0                  1                629            0

# %%
#Get the min, max, average, and number of missing values in the
#num_bottles_plastic column - code removed by Dr. R
# Out:
#    MIN(num_bottles_plastic)  MAX(num_bottles_plastic)  \
# 0                       0.0                    9830.0
#
#    AVG(num_bottles_plastic)  num_missing
# 0               2219.330645            1

# %%
#Get the min, max, average, and number of missing values in the
#num_polystyrene column - code removed by Dr. R
# Out:
#    MIN(num_polystyrene)  MAX(num_polystyrene)  AVG(num_polystyrene)  \
# 0                   0.0               11528.0           1436.868952
#
#    num_missing
# 0            1

# %%
#Get the min, max, average, and number of missing values in the
#num_cig_butts column  - code removed by Dr. R
# Out:
#    MIN(num_cig_butts)  MAX(num_cig_butts)  AVG(num_cig_butts)  num_missing
# 0                 0.0            310000.0        13728.122984            1

# %%
#Get the min, max, average, and number of missing values in the
#num_bottles_glass column - code removed by Dr. R
# Out:
#    MIN(num_bottles_glass)  MAX(num_bottles_glass)  AVG(num_bottles_glass)  \
# 0                     0.0                   110.0               20.955526
#
#    num_missing
# 0          251

# %%
#Get the min, max, average, and number of missing values in the
#num_plastic_bags column - code removed by Dr. R
# Out:
#    MIN(num_plastic_bags)  MAX(num_plastic_bags)  AVG(num_plastic_bags)  \
# 0                    0.0                13450.0             983.998992
#
#    num_missing
# 0            1

# %%
#Get the min, max, average, and number of missing values in the
#num_wrappers column - code removed by Dr. R
# Out:
#    MIN(num_wrappers)  MAX(num_wrappers)  AVG(num_wrappers)  num_missing
# 0                0.0            20100.0        2238.764429          144

# %%
#Get the min, max, average, and number of missing values in the
#num_sports_balls column - code removed by Dr. R
# Out:
#    MIN(num_sports_balls)  MAX(num_sports_balls)  AVG(num_sports_balls)  \
# 0                    0.0                   56.0              13.594595
#
#    num_missing
# 0          364

# %%
#Get the min, max, average, and number of missing values in the
#num_homes_powered column - code removed by Dr. R
# Out:
#    MIN(num_homes_powered)  MAX(num_homes_powered)  AVG(num_homes_powered)  \
# 0                       0                      94                45.84995
#
#    num_missing
# 0            0

# %%
#Get the min, max, average, and number of missing values in the
#weight_tons column - code removed by Dr. R
# Out:
#    MIN(weight_tons)  MAX(weight_tons)  AVG(weight_tons)  num_missing
# 0              0.61              5.62          2.966123            0

# %%
#Get the min, max, average, and number of missing values in the
#volume_cubic_yds column - code removed by Dr. R
# Out:
#    MIN(volume_cubic_yds)  MAX(volume_cubic_yds)  AVG(volume_cubic_yds)  \
# 0                      5                     20              14.919436
#
#    num_missing
# 0            0

# %% [markdown]
# ---

# %% [markdown]
# ### 2.3 The Baltimore Traffic Table
#
# This second table was provided by the Baltimore Metropolitan Council (BMC), which is a nonprofit organization that works with elected government to improve Baltimore's quality of life.
#
# This table contains the year, Annual Average Daily Traffic, Annual Average Weekday Traffic, and some further information not relevant to this project. In order to join this table efficiently, we created a column relating the information from the intersections to the relative trash wheel. The Annual Average Daily traffic is the average number of vehicles expected to travel through the intersection in a given day.
#
# The closest relevant intersection that we used for Mr. Trash Wheel was Lombard St. 0.01 miles west of President St. This is on a bridge directly upstream from Mr. Trash Wheel, with the flow of the river delivering collected garbage to it.
#
# For Professor Trash Wheel, we reference information from S Lakewood Ave between Boston St and O'Donnell St. This is the nearest intersection available, slightly away from the wheel, but still along the waterway nearby.
#
# Captain Trash Wheel uses data from Exit 8 Ramp 8 on Interstate 895 Southbound to Frankfurst Ave.
#
# Finally, Gwynnda Trash Wheel's data is taken from Ramp 3 on Interstate 95 Northbound to Interstate 395 Northbound. This ramp is almost directly above the wheel and is a large meeting point for many roads.
#
# A direct link to the data can be found at the following website.
#  * https://bmc.maps.arcgis.com/apps/dashboards/95b90bda95ac4dab83daddb8befd2f44

# %%
#Show second highway_traffic table - code removed by Dr. R
# Out:
#     Year   AADT  AAWDT  Single_Unit  Combination_Unit  K_Factor  D_Factor  \
# 0   2024  32640  35250         0.00              0.00      0.00      0.00
# 1   2023  30975  32835         5.68              1.65      8.73    100.00
# 2   2022  30514  32964         5.68              1.65      8.73    100.00
# 3   2021  30323  32453         5.68              1.65      8.73    100.00
# 4   2020  26502  28622         5.68              1.65      8.73    100.00
# 5   2019  31731  33641         5.68              1.65      8.73    100.00
# 6   2018  31730  33950         5.68              1.65      8.73    100.00
# 7   2017  33775  36145         5.68              1.65      7.69    100.00
# 8   2016  32974  35284         5.68              1.65      7.69    100.00
# 9   2015  32353  34623         5.68              1.65      7.69    100.00
# 10  2024   5110   5520         0.00              0.00      0.00      0.00
# 11  2023   4545   4825         0.00              0.00      8.39     88.24
# ...

# %% [markdown]
# ## 3. Results

# %% [markdown]
# The purpose of the trash wheels is to raise public awareness about pollution in local waterways. This dataset provides an opportunity to evaluate the program's effectiveness by analyzing trends in both the amount and composition of the garbage collected. In this section, we analyze how garbage collection has changed over time, assess the relationship between different types of waste, and examine the potential impact of human activity.

# %% [markdown]
# ### 3.1 -  Q: How has the amount of garbage collected changed over time?

# %% [markdown]
# This question is asked to determine if the wheels have effectively reduced pollution by increasing public awareness.

# %%
#This code retrieves the year, along with the total weight of trash for all
#trash wheels per year - code removed by Dr. R
# Out:
#    year  trash_weight_per_year
# 0  2014                 141.35
# 1  2015                 238.80
# 2  2016                 164.59
# 3  2017                 211.41
# 4  2018                 363.03
# 5  2019                 237.67
# 6  2020                 245.87
# 7  2021                 371.00
# 8  2022                 467.13
# 9  2023                 504.51

# %%
#This code retrieves the year, along with the total weight of trash each year
#specifically for Mister Trash Wheel - code removed by Dr. R
# Out:
#    year  mr_weight_per_year
# 0  2014              141.35
# 1  2015              238.80
# 2  2016              164.59
# 3  2017              174.84
# 4  2018              310.39
# 5  2019              200.24
# 6  2020              216.68
# 7  2021              185.53
# 8  2022              179.63
# 9  2023              207.49

# %%
#This code retrieves the year each wheel was implemented - code removed by Dr. R
# Out:
#               wheel_name  MIN(year)
# 0    Captain Trash Wheel       2018
# 1    Gwynnda Trash Wheel       2021
# 2     Mister Trash Wheel       2014
# 3  Professor Trash Wheel       2017

# %%
#This code contains descriptive information about the data, so that we could
#use it to format our line graph - code removed by Dr. R
# Out:
#              year  trash_weight_per_year
# count    10.00000              10.000000
# mean   2018.50000             294.536000
# std       3.02765             124.893915
# min    2014.00000             141.350000
# 25%    2016.25000             217.975000
# 50%    2018.50000             242.335000
# 75%    2020.75000             369.007500
# max    2023.00000             504.510000

# %%
#In this code cell, we create a line graph of the total trash collected
#across time, compared to Mr. Trash Wheel's collected trash as a baseline.
#Code removed by Dr. R

# %% [markdown]
# This graph shows the weight of garbage, in tons, across the years since the implementation of the trash wheels. All four trash wheels are combined onto the same line, denoted by a point at the year each was deployed. The total trash Mister Trash Wheel has accumulated per year was added as a baseline for comparison as it was the first, and longest-running wheel implemented.
#
# The original amount of trash collected in 2014 was around 149 tons. The implementation of Professor Trash Wheel increased the trash collected from approximately 175 to 215 tons. Until the deployment of Gwynnda Trash Wheel in 2021, even with the deployment of Captain Trash Wheel, the amount of trash collected stayed relevant to the baseline. Gwynnda Trash Wheel significantly increased the amount of trash collected, and by 2023, the total amount of garbage collect by all wheels was over 500 tons!
#
# This does not necessarily mean that the project is ineffective, as it is still removing waste from the Baltimore Harbor area. For example, if there was an increase in population of Baltimore from 2019-2023, having a stable amount of trash collected is better than having an increase. Since the amount of garbage collected is relatively stable for all 3 wheels from 2019-2023, we conclude that strategic deployment of additional trash wheels could decrease pollution in our waterways.
#
# Large fluctuations in the amount of garbage collected leads us to wonder if specific trash wheels are responsible for a disproportionate share of the waste.

# %% [markdown]
# ### 3.2 -  Q: Which wheel collects the most garbage?

# %% [markdown]
# With the introduction of new trash wheels, evaluating the amount of trash collected over time can lead to misunderstandings of the effectiveness of this program. We wanted to see which wheel collected the most garbage each year to see if more people are littering since the implementation of the wheels. If a new wheel increases the amount of trash collected significantly, this would explain an increase of garbage collected over time.

# %%
#This code cell creates dataframes for each of the wheels containing the year
#and sum of the weight of the garbage collected that year.
#Code removed by Dr. R

# %%
#In this code cell, we create a bar chart to evaluate which dumpster had the
#most garbage collected each year - code removed by Dr. R

# %% [markdown]
# From this visualization, we can determine that Mr Trash Wheel is a significant contributor in the collection of trash. The implementation of Professor Trash Wheel created a small but noteable increase in garbage collected per year. Meanwhile, the deployment of Captain Trash Wheel marginally affected the totals. In 2021, Gwynnda Trash Wheel was placed at the base of Gwynnda Falls in Baltimore, Maryland. It initially seems to match the collection rate of Mr Trash Wheel, but immediately surpasses it in 2022 and 2023.
#
# This does not necessarily mean that more people are littering, but that the implementation of more trash wheels is increasing the amount of garbage collected per year. On one hand, this is a bad thing. This means that the public disposal of garbage varies from place to place, suggesting a need for public awareness of littering. On the other hand, a larger amount of garbage collected means that less of it is ending up in the ocean.
#
# Differences in waste collected may be influenced by human activity. To explore this further, we evaluate the potential relationship between traffic volume and the amount of litter collected.

# %% [markdown]
# ### 3.3 -  Q: Does the amount of trash collected increase with traffic?

# %% [markdown]
# The trash wheels are placed near roads in the Baltimore harbor. We asked this question to see if the amount of traffic has is related to the amount of trash being thrown into the harbor.

# %%
#In this code cell, we join the Baltimore Traffic Table
# and the trash wheel table using title and year.  Code removed by Dr. R
# Out:
#         title  Year   AADT  total_weight_tons
# 0     captain  2023   1245               4.84
# 1     gwynnda  2023  38142             261.99
# 2      mister  2023  30975             207.49
# 3   professor  2023   4545              30.19
# 4     captain  2022   1205               3.34
# 5     gwynnda  2022  37571             248.25
# 6      mister  2022  30514             179.63
# 7   professor  2022   4474              35.91
# 8     captain  2021   1185               7.16
# 9     gwynnda  2021  37350             142.92
# 10     mister  2021  30323             185.53
# 11  professor  2021   4443              35.39
# 12    captain  2020   1045               5.79
# 13     mister  2020  26502             216.68
# 14  professor  2020   3882              23.40
# 15    captain  2019   1294               7.39
# 16     mister  2019  31731             200.24
# 17  professor  2019   4641              30.04
# 18    captain  2018   1283               8.83
# ...

# %%
#In this code cell, we create a scatter plot to evaluate the
#relationship between traffic and litter. Code removed by Dr. R

# %%
#Here we calculate the correlation coefficient - code removed by Dr. R
# Out:
# np.float64(0.9409822227680636)

# %% [markdown]
# This graph shows the average daily traffic of the closest intersection and the total yearly garbage weight for each trash wheel.
#
# This relationship between the number of cars per day and the trash collected per year is described by a correlation coefficient of 0.94. This shows a strong positive linear relationship between the two. It is possible we see this relationship as we tend to see more litter along roadways as people often throw garbage from their cars while driving. From personal observation, higher-traffic roads seem to have more visible garbage than less-traveled walking paths.
#
# Because we are missing data points for mid-range traffic values, we cannot be fully certain that the reported positive trend would continue across the entire range. Further data collection would be necessary to validate this relationship across all levels of traffic.
#
# While traffic volume may reveal the human influence on the amount of garbage collected, it does little to inform us what that trash is made of. To better understand the composition, we evaluate the distribution of plastic bottles collected by each trash wheel.

# %% [markdown]
# ### 3.4 -  Q: Is one trash wheel collecting a higher concentration of plastic bottles?

# %% [markdown]
# The trash wheels each collect varying amounts of trash. We asked this question to determine if a certain trash wheel is collecting a higher concentration of plastic bottles per dumpster load.

# %%
#This code cell creates dataframes for each of the trash wheels.
#Code removed by Dr. R

# %%
#This code cell calculates the weights for each bin count to translate
#counts to percentages for each histogram in this visualization, respective
#to each trash wheel - code removed by Dr. R

# %%
#In this code cell, we create a histogram of the percentage of occurrences of the
#amount of plastic bottles in each dumpster, for each trash wheel.
#Code removed by Dr. R

# %%
#These four cells retrieve statistical data for the
#number of plastic bottles collected by each trash wheel
#Code removed by Dr. R.
# Out:
# count     629.000000
# mean     1981.168521
# std      1058.817901
# min        80.000000
# 25%      1020.000000
# 50%      1900.000000
# 75%      2780.000000
# max      5960.000000
# Name: num_bottles_plastic, dtype: float64

# %%
#num_bottles_plastic  - code removed by Dr. R
# Out:
# count     113.000000
# mean     5151.734513
# std      2293.373689
# min       657.000000
# 25%      3700.000000
# 50%      4800.000000
# 75%      6800.000000
# max      9830.000000
# Name: num_bottles_plastic, dtype: float64

# %%
#num_bottles_plastic - code removed by Dr. R
# Out:
# count      30.000000
# mean     1462.100000
# std       691.647626
# min       103.000000
# 25%      1020.000000
# 50%      1300.000000
# 75%      1837.500000
# max      3450.000000
# Name: num_bottles_plastic, dtype: float64

# %%
#num_bottles_plastic - code removed by Dr. R
# Out:
# count     220.000000
# mean     1497.327273
# std      1075.307267
# min         0.000000
# 25%       640.000000
# 50%      1200.000000
# 75%      2100.000000
# max      5400.000000
# Name: num_bottles_plastic, dtype: float64

# %% [markdown]
# This histogram shows the percentage of occurrences of the plastic bottles in dumpster loads for each trash wheel separately.
#
# Mr. Trash Wheel collects about 1981 plastic bottles on average, but has a standard deviation of 1059 bottles. This suggests that plastic bottle collection is highly inconsistent between collections.
#
# Professor Trash Wheel averages approximately 5151 plastic bottles with a standard deviation of 2293 bottles. This makes a typical range of about 2800 to 7400 bottles. This is an even more exaggerated range than Mr. Trash Wheel, suggesting that there is external influence on the amount of bottles collected. This could be due to public gatherings or differences in weather patterns across the harbor area.
#
# Captain Trash Wheel averages 1462 bottles with a standard deviation of 691 bottles. This is a moderate deviation, especially compared to the other wheels. This is reflected in the graph having a large spike between 1000 and 1500 bottles for Captain Trash Wheel.
#
# Gwynnda Trash Wheel sees approximately 1497 bottles on average. The standard deviation of 1075 bottles shows extreme inconsistency, as it's over 70% of the mean. This could mean that the collection of bottles is highly influenced by storm activity and possibly runoff. We also have the least amount of data available for this wheel, as perhaps the data could become more predictable over time. Overall, each trash wheel shows variation in the amount of bottles collected. This is possibly due to environmental or human influence.
#
# The distribution of plastic bottles collected leads us to wonder if there is an association between the types of waste. To determine this, we analyze the association between the amounts of wrappers and plastic bags collected.

# %% [markdown]
# ### 3.5 -  Q: Is the relationship between wrappers and bags similar for each trash wheel?

# %% [markdown]
# Each trash wheel is at a different location so we wanted to see if the relationship between the number of wrappers and bags per dumpster is similar.

# %%
#This, and the three subsequent code cells retrieve the the number of plastic bags
#and wrappers relative to the wheel that collected them - code removed by Dr. R
# Out:
#            wheel_name  num_plastic_bags  num_wrappers
# 0  Mister Trash Wheel             584.0        1162.0
# 1  Mister Trash Wheel             496.0         874.0
# 2  Mister Trash Wheel            1080.0        2032.0
# 3  Mister Trash Wheel             896.0        1971.0
# 4  Mister Trash Wheel             368.0         753.0
# 5  Mister Trash Wheel             672.0        1144.0
# 6  Mister Trash Wheel             416.0         692.0
# 7  Mister Trash Wheel            1552.0        3015.0
# 8  Mister Trash Wheel             984.0        1988.0
# 9  Mister Trash Wheel             448.0        1066.0

# %%
#professor wheel - code removed by Dr. R
# Out:
#               wheel_name  num_plastic_bags  num_wrappers
# 0  Professor Trash Wheel            3100.0       15600.0
# 1  Professor Trash Wheel            5630.0       16700.0
# 2  Professor Trash Wheel            6430.0       12400.0
# 3  Professor Trash Wheel            5870.0       11030.0
# 4  Professor Trash Wheel            7450.0       15340.0
# 5  Professor Trash Wheel            9560.0       13470.0
# 6  Professor Trash Wheel           11500.0       18620.0
# 7  Professor Trash Wheel            9970.0       14670.0
# 8  Professor Trash Wheel           12340.0       16580.0
# 9  Professor Trash Wheel           13450.0       17220.0

# %%
#Captain Trash Wheel  - code removed by Dr. R
c_bags_vs_wrappers = pd.read_sql_query(sql_statement, conn)
c_bags_vs_wrappers.head(10)
# Out:
#             wheel_name  num_plastic_bags  num_wrappers
# 0  Captain Trash Wheel            1420.0           NaN
# 1  Captain Trash Wheel            1810.0           NaN
# 2  Captain Trash Wheel            2220.0           NaN
# 3  Captain Trash Wheel            1130.0           NaN
# 4  Captain Trash Wheel            2100.0           NaN
# 5  Captain Trash Wheel             920.0           NaN
# 6  Captain Trash Wheel            1200.0           NaN
# 7  Captain Trash Wheel            1650.0           NaN
# 8  Captain Trash Wheel            1900.0           NaN
# 9  Captain Trash Wheel            1450.0           NaN

# %%
#Gwynnda Trash Wheel - code removed by Dr. R
# Out:
#             wheel_name  num_plastic_bags  num_wrappers
# 0  Gwynnda Trash Wheel            1800.0           NaN
# 1  Gwynnda Trash Wheel            2200.0           NaN
# 2  Gwynnda Trash Wheel            2400.0           NaN
# 3  Gwynnda Trash Wheel            1800.0           NaN
# 4  Gwynnda Trash Wheel            2700.0           NaN
# 5  Gwynnda Trash Wheel            3000.0           NaN
# 6  Gwynnda Trash Wheel            3200.0           NaN
# 7  Gwynnda Trash Wheel            3600.0           NaN
# 8  Gwynnda Trash Wheel            1000.0           NaN
# 9  Gwynnda Trash Wheel             360.0           NaN

# %%
#In this code cell, we create a scatter plot comparing the number of plastic bags
#to the number of wrappers in each dumpster load, separated by each wheel
#Code removed by Dr. R

# %%
#This code cell creates correlation tables for each wheels scatter plot
#and calculates their respective correlation coefficients
#Code removed by Dr. R
# Out:
# Mister Trash Wheel r = 0.8508257987193834
# Professor Trash Wheel r = 0.6999723608539135
# Captain Trash Wheel r = 0.3453017583758409
# Gwynnda Trash Wheel r = 0.8464553690497992

# %% [markdown]
# This scatter plot shows the number of plastic bags and wrappers per dumpster for each trash wheel since their inception.
#
# Each trash wheel shows a distinct line with the data gathered. Mister and Gwynnda both have an high correlation coefficient of 0.85 and 0.84 and Professor has a slightly lower but still correlation coefficient of 0.69, which is decent, but is likely due to the inconsistant amount of wrappers and plastic bags compared to the other Trash Wheels. Captain does have a lower coefficient of 0.34. This is due to the fact that there are only four data points for plastic bags and wrappers even, so the data points still show a trend.
#
# Each trash wheel's correlation coefficient is simlar with Mister and Gwynnd, being almost the same. While Captain does have a low coefficient, it still shows a sign of trend between wrappers and plastic bags. Though when it comes to the division between the trash wheels, it's possibly due to the amount of dumpsters collected, the locations of the trash wheel, and if not every type of trash floats the same way.

# %% [markdown]
# ## 4. Conclusion

# %% [markdown]
# Upon evaluating this dataset, there has not been a significant decrease in the amount of garbage collected. In fact, the overall amount of waste seems to be increasing. However, this does not indicate that the Healthy Harbor Initiative has been unsuccessful. The deployment of additional trash wheels likely contributes to the increased waste collection. This may show improved collection rather than a rise in littering.
#
# The observed relationship between traffic volume and waste collection suggests that highly trafficked roadways should be considered as locations for future wheels. Increased enforcement and signage denoting penalties for littering may help reduce the amount of roadside waste.
#
# Plastic waste continues to be a major concern, and this dataset supports that. The prevalence of plastic bottles and the strong correlation between wrappers and plastic bags may indicate that people are using bags to discard multiple garbage items. More widespread use of biodegradable packaging could help reduce the long-term environmental impact of this type of litter.
#
# If a more comprehensive dataset were available, one with more collections per wheel, potentially in the future, it would allow for a clearer picture of long-term trends. Since the effects of the trash wheels may take years to appear, additional data points would strengthen our conclusions. Ideally, if we had more time, we would like to evaluate the effect the surrounding environment has on waste collection. Specifically, how do residential, commercial, and industrial areas influence the type of waste collected?
#
# These questions represent important next steps in understanding and possibly expanding the impact of the Healthy Harbor Initiative.
