# %%
# imports - code removed by Dr. R

# %% [markdown]
# ---
# #### CS 260 Database and Data Visualizsation - Final Project - SP24
# ---
#
# # Dementia Patients

# %% [markdown]
# ### By: Sophia Evangelista and Veronica Reilly

# %% [markdown]
# ---
#
# ## 1. Introduction

# %% [markdown]
# For this project, our group explored dementia patient health. Dementia is a condition that that affects cognitive abilities such as memory, thinking, and social abilities.  We will first explore common risk factors of dementia including genetic risks, age, cardiovascular risks such as high blood pressure and diabetes, and sleep problems ([Dementia - Symptoms and Causes](https://www.mayoclinic.org/diseases-conditions/dementia/symptoms-causes/syc-20352013)). Then we will look at treatments for dementia, such as various medications and their dosages. Finally, we will look at the most prominant symptom of dementia, cognitive function. Our dataset includes records on patients and different health factors, and whether or not they have been diagnosed with dementia.
#
# We first looked at sleep quality, as we wanted to see if having issues with sleep could be associated with dementia. We found in our bar graph that more of the dementia patients reported having poor sleep quality than good sleep quality. Next, we asked if the APOE ε4 allele, a gene associated with Alzheimer's disease, was more common in those diagnosed with dementia. We found an overwhelming amount of dementia patients tested positive for having the APOE ε4 allele, while those who did not have the allele were evenly distributed between having dementia and not having dementia. We then wanted to see if dementia is more common in older patients. We discovered that dementia, in this study, is most common in those ages 60 to 65 and 85 to 90. Chronic health conditions can be considered as a risk factor in dementia diagnosis, however, our dataset did not suggest that dementia is more common in those with chronic health conditions.
#
# We then moved on to look at some of the main medication that dementia patients take. We saw that most of the dementia patients in this study take Memantine, followed by Galantamine and Rivastigmine. Along with Memantine being prescribed the most frequently, we also found it is given at the highest dosage.
#
# We then decided to explore on the main symptom of dementia, cognitive function. We first asked if dementia had any relation to cognitive score, the result of a test given to measure one's cognitive function. Based on what we observed about our data set, we found that cognitive score is most likely related to whether a patient has dementia or not. All the patients with dementia scored less than 8, while all of the patients without dementia scored over 8. From here, we wanted to see if there was any linear correlation between the cognitive score and medication dosage. Our results showed us that there is very little to no correlation between cognitive score and prescription dosage. Finally, we asked if the patients with dementia were more likely to have growing stress levels. We observed that many of the patients in this study with dementia had increasing stress levels.

# %% [markdown]
# ---
#
# ## 2. Data

# %% [markdown]
# A direct link to the data can be found at the following website:
#  * [Dementia Dataset](https://www.kaggle.com/datasets/kaggler2412/dementia-patient-health-and-prescriptions-dataset)
#
#
# According to Kaggle, the data was collected from consultation with healthcare professionals, the National Health Service (UK), and google scholar. The data was also gathered from open source databases. It was last updated a month ago, and is expected to be updated every month.
#
# Kaggle also provides this additional resource alongside the data:
# [Additional Resource](https://www.nia.nih.gov/health/alzheimers-treatment/how-alzheimers-disease-treated#:~:text=Galantamine%2C%20rivastigmine%2C%20and%20donepezil%20are,some%20cognitive%20and%20behavioral%20symptoms)

# %%
#In this cell, we load the data.
#Code removed by Dr. R

# %% [markdown]
# Our main table, dementia, is show below.

# %%
#Show the rows of the table  - code removed by Dr. R
# Out:
#        id  diabetic  alcohol_consumption  hr_per_min  blood_oxygen_level  \
# 0       1         1             0.084974          98           96.230743
# 1       2         0             0.016973          78           93.032122
# 2       3         0             0.009000          89           93.566504
# 3       4         0             0.086437          60           93.906510
# 4       5         1             0.150747          67           97.508994
# ..    ...       ...                  ...         ...                 ...
# 995   996         1             0.081825          87           93.851963
# 996   997         1             0.145249          97           94.522391
# 997   998         1             0.073692          65           98.578388
# 998   999         0             0.037347          71           91.298580
# 999  1000         0             0.085969          90           95.522825
#
#      body_temp     weight  mri_delay_time prescription  prescription_dosage  \
# ...

# %% [markdown]
# Our secondary table, mentalhealth, is shown below. We will be utilizing the growing stress column.
#
#  * *Note: the originial dataset ([Click Here](https://www.kaggle.com/datasets/divaniazzahra/mental-health-dataset)) consists of individual survey results that track trends in mental health. The originial dataset had over 20,000 rows representing different individuals. We selected only the first 1000 rows, as we were using the data to conduct an inner join anyways, and the original set was too large for github.*

# %%
#Show the rows of the second table - code removed by Dr. R
# Out:
#        id        Timestamp  Gender        Country Occupation self_employed  \
# 0       1  8/27/2014 11:29  Female  United States  Corporate          None
# 1       2  8/27/2014 11:31  Female  United States  Corporate          None
# 2       3  8/27/2014 11:32  Female  United States  Corporate          None
# 3       4  8/27/2014 11:37  Female  United States  Corporate            No
# 4       5  8/27/2014 11:43  Female  United States  Corporate            No
# ..    ...              ...     ...            ...        ...           ...
# 995   996  8/27/2014 14:13  Female  United States    Student            No
# 996   997  8/27/2014 14:16  Female  United States    Student            No
# 997   998  8/27/2014 14:19  Female  United States    Student            No
# 998   999  8/27/2014 14:27  Female  United States    Student            No
# 999  1000  8/27/2014 14:31  Female  United States    Student            No
#
# ...

# %% [markdown]
# The growing stress column in the mentalhealth table is a categorical variable which identifies if the current level of stress felt by the patient is growing or not. So, is the patient's stress level increasing or not. It has 0 missing values and 2 distinct values, yes and no.

# %%
#Get the number of missing values in the growing stress column - code removed by Dr. R
# Out:
#    missing_values
# 0               0

# %%
#Get the distinct values in the growing stress column - code removed by Dr. R
# Out:
#   Growing_Stress
# 0            Yes
# 1             No

# %% [markdown]
# ### 2.1 Summary of Variables within the dementia Table

# %% [markdown]
# The dementia table has 25 columns/variables and 1000 rows.  All variables are explained in this section.
#
# Note that the table was read in from a csv, but had we created a formal SQLite database for the table, the schema would have been as follows.
#
# ```
# CREATE TABLE "dementia" (
# 	"id"	INTEGER,
# 	"diabetic"	INTEGER,
# 	"alcohol_consumption"	REAL,
# 	"hr_per_min"	INTEGER,
# 	"blood_oxygen_level"	REAL,
# 	"body_temp"	REAL,
# 	"weight"	REAL,
# 	"mri_delay_time"	REAL,
# 	"prescription"	TEXT,
# 	"prescription_dosage"	REAL,
# 	"age"	INTEGER,
# 	"education"	TEXT,
# 	"dominant_hand"	TEXT,
# 	"gender"	TEXT,
# 	"family_history"	TEXT,
# 	"smoker"	TEXT,
# 	"apoe"	TEXT,
# 	"physical_activity"	TEXT,
# 	"depression"	TEXT,
# 	"cognitive_score"	INTEGER,
# 	"medication_history"	TEXT,
# 	"diet"	TEXT,
# 	"sleep_quality"	TEXT,
# 	"health_condition"	TEXT,
# 	"dementia"	INTEGER,
# 	PRIMARY KEY("id")
# );
# ```
#
# Here are the variables, their descriptions, their units, their types, and some descriptive statistics.
#
# **CATEGORICAL VARIABLES**
#
# * **id** – identifier for each patient
#     * Number of missing values: 0
#     * Contains 1000 distinct values:
#         * 1 - 1000
#
# * **diabetic** – binary indicator of whether a patient has been diagnosed with diabetes
#     * Number of missing values: 0
#     * Contains 2 distinct values:
#         * 0 - the patient has not been diagnosed with diabetes
#         * 1 - the patient has been diagnosed with diabetes
#
# * **prescription** – the specific medication prescribed to the patient
#     * Number of missing values: 515
#     * Contains 5 distinct values:
#         * None - No value - there is no record of the patient being prescribed medication
#         * Galantamine - the patient has been prescribed Galantamine
#         * Donepezil - the patient has been prescribed Donepezil
#         * Memantine - the patient has been prescribed Memantine
#         * Rivastigmine - the patient has been prescribed Rivastigmine
#
# * **education** – the highest level of education attained by the patient
#     * Number of missing values: 0
#     * Contains 4 distinct values:
#         * Primary School - the patient completed primary school
#         * Secondary School - the patient completed secondary school
#         * No School - the patient did not complete any schooling
#         * Diploma/Degree - patient attained a diploma/degree
#
# * **dominant_hand** – indicates the dominant hand of the patient
#     * Number of missing values: 0
#     * Contains 2 distinct values:
#         * Right - the patient is right hand dominant
#         * Left - the patient is left hand dominant
#
# * **gender** – gender of the patient
#     * Number of missing values: 0
#     * Contains 2 distinct values:
#         * Male - the patient is male
#         * Female - the patient is female
#
# * **family_history** – indicates if the patient has a family history of dementia
#     * Number of missing values: 0
#     * Contains 2 distinct values:
#         * Yes - the patient has a family history of dementia
#         * No - the patient does not have a family history of dementia
#
# * **smoker** – indicates the pateint's smoking habits
#     * Number of missing values: 0
#     * Contains 3 distinct values:
#         * Current Smoker - the patient is an active smoker
#         * Former Smoker - the patient used to smoke, but does not anymore
#         * Never Smoked - the patient has no smoking history
#
# * **apoe** – indicates the presence of the APOE ε4 allele, a genetic variant associated with Alzheimer's disease
#     * Number of missing values: 0
#     * Contains 2 distinct values:
#         * Negative - the patient does not have the APOE ε4 allele assosiated with alzehimers disease
#         * Positive - the patient has the APOE ε4 allele assosiated with alzehimers disease
#
# * **physical_activity** – indicates the level of physical activity of the patient
#     * Number of missing values: 0
#     * Contains 3 distinct values:
#         * Sedentary - the patient is not active
#         * Moderate Activity - the patient is moderately active
#         * Mild Activity - the patient is mildly active
#
# * **depression** – indicates whether the patient has depression
#     * Number of missing values: 0
#     * Contains 2 distinct values:
#         * Yes  - the patient suffers from depression
#         * No - the patient does not suffer from depression
#
# * **medication_history** – indicates whether the patient has a history of medication usage
#     * Number of missing values: 0
#     * Contains 2 distinct values:
#         * Yes - the patient has a history of medication useage
#         * No - the patient does not have a history of medication usage
#
# * **diet** – describes the patients diet
#     * Number of missing values: 0
#     * Contains 3 distinct values:
#         * Low-Carb Diet - the patient follows a low-carb diet
#         * Mediterranean Diet - the patient follows a mediterranean diet
#         * Balanced Diet - the patient follows a balanced diet
#
# * **sleep_quality** – assesses the quality of the patient's sleep
#
#     * Number of missing values: 0
#     * Contains 2 distinct values:
#         * Good - the patient has good sleep quality
#         * Poor - the patient has poor sleep quality
#
# * **health_condition** – notes any chronic health conditions that patient has
#     * Number of missing values: 0
#     * Contains 4 distinct values:
#         * Diabetes - the patient has been diagnosed with diabetes
#         * Heart Disease - the patient has been diagnosed with heart disease
#         * Hypertension - the patient has been diagnosed with hypertension
#         * None - the patient does not have any chronic health conditions
#
# * **dementia** – binary indicator of whether a patient has been diagnosed with dementia
#     * Number of missing values: 0
#     * Contains 2 distinct values:
#         * 0 - the patient has not been diagnosed with dementia
#         * 1 - the patient has been diagnosed with dementia
#
# **QUANTITATIVE DISCRETE VARIABLES**
#
# * **hr_per_min** – number of heartbeats per minute
#     * Number of missing values: 0
#     * Units: beats per minute (BPM)
#     * max value: 100
#     * min value: 60
#     * average value: 79.383
#
# * **prescription_dosage** – the amount medication prescribed if the patient is on medication
#     * Number of missing values: 515
#     * Units: milligrams (mg)
#     * max value: 23
#     * min value: 1.5
#     * average value: 9.213402
#
# * **age** – age of the patient
#     * Number of missing values: 0
#     * Units: years
#     * max value: 90
#     * min value: 60
#     * average value: 74.908
#
# * **cognitive_score** – patient score from a cogntive test which directly measures cognitive function
#     * Number of missing values: 0
#     * Units: no units given
#     * max value: 10
#     * min value: 0
#     * average value: 6.383
#
# **QUANTITATIVE  CONTINUOUS VARIABLES**
#
# * **alcohol_consumption** – measures the alcohol consumption level of patients
#     * Number of missing values: 0
#     * Units: blood alcohol concentration (BAC)
#     * max value: 0.199866
#     * min value: 0.000414
#     * average value: 0.098429
#
# * **blood_oxygen_level** – the saturation of oxygen in the blood
#     * Number of missing values: 0
#     * Units: millimeters of mercury (mm Hg)
#     * max value: 99.99923
#     * min value: 90.010677
#     * average value: 95.226051
#
# * **body_temp** – the measured temperature of the body
#     * Number of missing values: 0
#     * Units: celsius (C)
#     * max value: 37.496809
#     * min value: 36.002108
#     * average value: 36.761513
#
# * **weight** – the mass of the patient
#     * Number of missing values: 0
#     * Units: kilograms (kg)
#     * max value: 99.982722
#     * min value: 50.069731
#     * average value: 74.321326
#
# * **mri_delay_time** – the time delay in obtaining an MRI scan
#     * Number of missing values: 0
#     * Units: no units given
#     * max value: 59.957599
#     * min value: 0.094684
#     * average value: 30.103568

# %% [markdown]
# ### 2.2 Code used to Summarize Variables

# %% [markdown]
# In this section we include the code used to describe the variables in the previous section.

# %% [markdown]
# ---

# %%
#Get the number of missing values in the id column - code removed by Dr. R
# Out:
#    missing_values
# 0               0

# %%
#Get the distinct values in the id column - code removed by Dr. R
# Out:
#        id
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 995   996
# 996   997
# 997   998
# 998   999
# 999  1000
#
# [1000 rows x 1 columns]

# %%
#Get the number of missing values in the diabetic column - code removed by Dr. R
# Out:
#    missing_values
# 0               0

# %%
#Get the distinct values in the diabetic column - code removed by Dr. R
# Out:
#    diabetic
# 0         1
# 1         0

# %%
#Get the min, max, average, and number of missing values in the alcohol_consumption column - code removed by Dr. R
# Out:
#    missing_values  MIN(alcohol_consumption)  MAX(alcohol_consumption)  \
# 0               0                  0.000414                  0.199866
#
#    AVG(alcohol_consumption)
# 0                  0.098429

# %%
#Get the min, max, average, and number of missing values in the hr_per_min column - code removed by Dr. R
# Out:
#    missing_values  MIN(hr_per_min)  MAX(hr_per_min)  AVG(hr_per_min)
# 0               0               60              100           79.383

# %%
#Get the min, max, average, and number of missing values in the blood_oxygen_level column - code removed by Dr. R
# Out:
#    missing_values  MIN(blood_oxygen_level)  MAX(blood_oxygen_level)  \
# 0               0                90.010677                 99.99923
#
#    AVG(blood_oxygen_level)
# 0                95.226051

# %%
#Get the min, max, average, and number of missing values in the body_temp column - code removed by Dr. R
# Out:
#    missing_values  MIN(body_temp)  MAX(body_temp)  AVG(body_temp)
# 0               0       36.002108       37.496809       36.761513

# %%
#Get the min, max, average, and number of missing values in the weight column - code removed by Dr. R
# Out:
#    missing_values  MIN(weight)  MAX(weight)  AVG(weight)
# 0               0    50.069731    99.982722    74.321326

# %%
#Get the min, max, average, and number of missing values in the mri_delay_time column - code removed by Dr. R
# Out:
#    missing_values  MIN(mri_delay_time)  MAX(mri_delay_time)  \
# 0               0             0.094684            59.957599
#
#    AVG(mri_delay_time)
# 0            30.103568

# %%
#Get the number of missing values in the prescription column - code removed by Dr. R
# Out:
#    missing_values
# 0             515

# %%
#Get the distinct values in the precription column - code removed by Dr. R
# Out:
#    prescription
# 0          None
# 1   Galantamine
# 2     Donepezil
# 3     Memantine
# 4  Rivastigmine

# %%
#Get the min, max, average, and number of missing values in the prescription_dosage column - code removed by Dr. R
# Out:
#    missing_values  MIN(prescription_dosage)  MAX(prescription_dosage)  \
# 0             515                       1.5                      23.0
#
#    AVG(prescription_dosage)
# 0                  9.213402

# %%
#Get the min, max, average, and number of missing values in the age column - code removed by Dr. R
# Out:
#    missing_values  MIN(age)  MAX(age)  AVG(age)
# 0               0        60        90    74.908

# %%
#Get the missing values in the education column - code removed by Dr. R
# Out:
#    missing_values
# 0               0

# %%
#Get the distinct values in the education column - code removed by Dr. R
# Out:
#           education
# 0    Primary School
# 1  Secondary School
# 2         No School
# 3    Diploma/Degree

# %%
#Get the missing values in the dominant_hand column - code removed by Dr. R
# Out:
#    missing_value
# 0              0

# %%
#Get the distinct values in the dominant_hand column - code removed by Dr. R
# Out:
#   dominant_hand
# 0          Left
# 1         Right

# %%
#Get the missing values in the gender column - code removed by Dr. R
# Out:
#    missing_value
# 0              0

# %%
#Get the distinct values in the gender column - code removed by Dr. R
# Out:
#    gender
# 0  Female
# 1    Male

# %%
#Get the missing values in the family_history column - code removed by Dr. R
# Out:
#    missing_value
# 0              0

# %%
#Get the distinct values in the family_history column - code removed by Dr. R
# Out:
#   family_history
# 0             No
# 1            Yes

# %%
#Get the missing values in the smoker column - code removed by Dr. R
# Out:
#    missing_value
# 0              0

# %%
#Get the distinct values in the smoker column - code removed by Dr. R
# Out:
#            smoker
# 0  Current Smoker
# 1   Former Smoker
# 2    Never Smoked

# %%
#Get the missing values in the apoe column - code removed by Dr. R
# Out:
#    missing_value
# 0              0

# %%
#Get the distinct values in the apoe column - code removed by Dr. R
# Out:
#        apoe
# 0  Negative
# 1  Positive

# %%
#Get the missing values in the physical_activity column - code removed by Dr. R
# Out:
#    missing_value
# 0              0

# %%
#Get the distinct values in the physical_activity column - code removed by Dr. R
# Out:
#    physical_activity
# 0          Sedentary
# 1  Moderate Activity
# 2      Mild Activity

# %%
#Get the missing values in the depression column - code removed by Dr. R
# Out:
#    missing_value
# 0              0

# %%
#Get the distinct values in the depression column - code removed by Dr. R
# Out:
#   depression
# 0         No
# 1        Yes

# %%
#Get the min, max, average, and number of missing values in the cognitive_score column  - code removed by Dr. R
# Out:
#    missing_values  MIN(cognitive_score)  MAX(cognitive_score)  \
# 0               0                     0                    10
#
#    AVG(cognitive_score)
# 0                 6.383

# %%
#Get the missing values in the medication_history column - code removed by Dr. R
# Out:
#    missing_value
# 0              0

# %%
#Get the distinct values in the medication_history column - code removed by Dr. R
# Out:
#   medication_history
# 0                 No
# 1                Yes

# %%
#Get the missing values in the diet column - code removed by Dr. R
# Out:
#    missing_value
# 0              0

# %%
#Get the distinct values in the diet column - code removed by Dr. R
# Out:
#                  diet
# 0       Low-Carb Diet
# 1  Mediterranean Diet
# 2       Balanced Diet

# %%
#Get the missing values in the sleep_quality column - code removed by Dr. R
# Out:
#    missing_value
# 0              0

# %%
#Get the distinct values in the sleep_quality column - code removed by Dr. R
# Out:
#   sleep_quality
# 0          Poor
# 1          Good

# %%
#Get the missing values in the health_condition column - code removed by Dr. R
# Out:
#    missing_value
# 0            179

# %%
#Get the distinct values in the health_condition column - code removed by Dr. R
# Out:
#   health_condition
# 0         Diabetes
# 1    Heart Disease
# 2     Hypertension
# 3             None

# %%
#Get the missing values in the dementia column - code removed by Dr. R
# Out:
#    missing_value
# 0              0

# %%
#Get the distinct values in the dementia column - code removed by Dr. R
# Out:
#    dementia
# 0         0
# 1         1

# %% [markdown]
# ## 3. Results

# %% [markdown]
# In this section we will begin to explore the data set to get insight on dementia patient health. This section consists of 5 bar charts, 2 histograms, 1 scatter plot, and 1 line graph to answer a series of questions about the patients in this study. We will look at common risk factors of dementia, treatments, and the symptoms and effects of dementia.
#
# ### 3.1 -  Q: Does sleep quality affect the risk of dementia?

# %% [markdown]
# One of the main risk factors of dementia is sleeping issues and poor sleep. This question is intended to look at patients with dementia and explore whether one's sleep quality can have an association with the diagnosis of dementia.

# %%
#SQL statement to get table of dementia patients and sleep quality without null values - code removed by Dr. R
# Out:
#   sleep_quality  num_sleep
# 0          Poor        264
# 1          Good        221

# %%
#Graph code
#bar chart of sleep quality in dementia patients - code removed by Dr. R

# %% [markdown]
# From this visualization, we found that more of the dementia patients in this study had poor sleep quality than good sleep quality. We believe this is reasonable as this visualization supports additional sources that indicate poor sleep habits may contribute to dementia, or be early signs of dementia ([Poor Sleep and Dementia](https://www.nia.nih.gov/news/lack-sleep-middle-age-may-increase-dementia-risk#:~:text=Studies%20have%20suggested%20that%20sleep%20patterns%20earlier%20in,to%20the%20disease%20or%20simply%20reflect%20early%20symptoms.)). Additionally, it makes sense that dementia is more common in those with poor sleep quality, as sleep is crucial for brain functionality ([Understanding Sleep](https://www.ninds.nih.gov/health-information/public-education/brain-basics/brain-basics-understanding-sleep#:~:text=Without%20sleep%20you%20can%E2%80%99t%20form%20or%20maintain%20the,and%20body%20stay%20remarkably%20active%20while%20you%20sleep.)). Without sleep, the brain cannot function properly, similar to how dementia causes a decline in cognitive performance.

# %% [markdown]
# Poor sleep is a risk factor of dementia that could be controlled, however, there are other risk factors of dementia that are more difficult to control. For example, there are certain genes, such as the APOE ε4 gene, that are unavoidable. Those who possess the APOE ε4 gene are more suseptible to Alzheimer's disease, a form of dementia.

# %% [markdown]
# ### 3.2 -  Q: Is dementia more common in those with the APOE ε4 allele?

# %% [markdown]
# This question helps us identiy if dementia is more common in patients with the APOE ε4 allele. The APOE ε4 allele is a genetic variant associated with Alzheimer's disease, a specific type of dementia.

# %%
#SQL statement to get table of dementia patients and apoe allelle without null values - code removed by Dr. R
# Out:
#        apoe  num_apoe
# 0  Positive       435
# 1  Negative        50

# %%
#bar chart of apoe allele in dementia patients - code removed by Dr. R

# %% [markdown]
# While it is evident that there are more dementia cases present amongst those with the APOE ε4 gene, it is imperative to compare this distribution with patients who do not have dementia as well. This will allow us to compare the presence of the APOE ε4 gene in the group of those with dementia and those without dementia.

# %%
#want to compare the allele in dementia patients to the allele in nondementia patients
#SQL statement to get table of non dementia patients and apoe allelle without null values
#Code removed by Dr. R
# Out:
#        apoe  num_apoe
# 0  Positive       259
# 1  Negative       256

# %%
#percentage of dementia patients with the allele
#Code removed by Dr. R
# Out:
#    perc_dem_allele
# 0        89.690722

# %%
#percentage of non dementia patients with the allele
#SQL statement to get table of non dementia patients and apoe allelle without null values
#Code removed by Dr. R
# Out:
#    perc_dem_allele
# 0        49.708738

# %%
#Graph code
#bar chart of apoe allele in dementia and nondementia patients
#Code removed by Dr. R

# %% [markdown]
# From this visualization, we can observe that dementia is more common in patients that test positive for the APOE ε4 allele, which aligns with research on dementia ([Dementia - Symptoms and Causes](https://www.mayoclinic.org/diseases-conditions/dementia/symptoms-causes/syc-20352013)). Approximately 90% of the patients in our study that have been diagnosed with dementia possess the APOE ε4 allele. Perhaps this makes sense because the allele is associated with Alzheimer's disease, which is the most common form of dementia. Of our patients without dementia, approximately 50% of them have the allele and 50% of them do not. This indicates that one could possess the APOE ε4 allele, yet avoid being diagnosed with dementia. Overall, it appears that those with the allele are more likely to be diagnosed with dementia than those without.

# %% [markdown]
# Like the APOE ε4 gene, there are many other risk factors of dementia that are difficult combat. Another risk factor of dementia that is unavoidable is aging.

# %% [markdown]
# ### 3.3 -  Q: Is dementia more common in older patients?

# %% [markdown]
# This visual looks at patients with demenita and without dementia across ages, allowing us to see if dementia is more prominent in certain ages.

# %%
#SQL statement to get a table of dementia patients
#Code removed by Dr. R
# Out:
#       id  diabetic  alcohol_consumption  hr_per_min  blood_oxygen_level  \
# 0      2         0             0.016973          78           93.032122
# 1      4         0             0.086437          60           93.906510
# 2      5         1             0.150747          67           97.508994
# 3      6         1             0.114028          94           94.546754
# 4      7         1             0.016194          90           96.423361
# ..   ...       ...                  ...         ...                 ...
# 480  993         1             0.139464          84           94.083170
# 481  994         0             0.128752          78           90.727275
# 482  995         1             0.002725          84           93.624111
# 483  996         1             0.081825          87           93.851963
# 484  999         0             0.037347          71           91.298580
#
#      body_temp     weight  mri_delay_time  prescription  prescription_dosage  \
# ...

# %%
#SQL statement to get a table of non-dementia patients
#Code removed by Dr. R
# Out:
#        id  diabetic  alcohol_consumption  hr_per_min  blood_oxygen_level  \
# 0       1         1             0.084974          98           96.230743
# 1       3         0             0.009000          89           93.566504
# 2       8         0             0.161158          98           92.007370
# 3       9         0             0.015754          69           99.859490
# 4      11         0             0.067486          97           91.974094
# ..    ...       ...                  ...         ...                 ...
# 510   986         1             0.017496          75           99.859658
# 511   992         1             0.019056          84           97.759803
# 512   997         1             0.145249          97           94.522391
# 513   998         1             0.073692          65           98.578388
# 514  1000         0             0.085969          90           95.522825
#
#      body_temp     weight  mri_delay_time prescription prescription_dosage  \
# ...

# %%
# multipliers to use percentages
#Code removed by Dr. R

# %%
# Graph code
#2 histograms of age based on dementia vs non-dementia patients
#Code removed by Dr. R

# %% [markdown]
# The visuzalization demonstrates that dementia is most prominent in patients in this study from age 65 and up. This makes sense because according to the Centers for Disease Control and Prevention, most cases of dementia affect those age 65 and older ([Alzheimer's Disease and Healthy Aging](https://www.cdc.gov/aging/dementia/index.html)). Our visualization shows more patients with dementia from the ages of 60 to 65 than patients without dementia.  We believe there is a higher percent of patients with dementia than without from ages 60 to 65 because this is a common starting age of dementia diagnosis. Additionally, as we get into a higher age range, such as patients ages 80 to 90, there are more patients without dementia than with dementia. Perhaps this suggests that as patients get older, if they have not yet been diagnosed with dementia they will not be diagnosed. Or, perhaps there are more patients without dementia from ages 80 to 90 than patients with dementia because they are generally in good health. The average life expectancy worldwide is only about 74 years old ([Avg Life Expectancy](https://database.earth/population/world/life-expectancy)), so perhaps if a patient is living into their 80s and 90s, they are in good health, thus bypassing dementia. Something else we believe after evaluating the percentage of dementia patients in each age range is that the histogram suggests that patients will either live with dementia for most of their senior life, being diagnosed from age 60 to 65, or just for the end of their life, being diagnosed from age 80.

# %% [markdown]
# Another risk factor of dementia that is difficult to avoid is chronic health conditions. While some chronic health conditions are preventable, many chronic health conditions are genetic, thus unavoidable. Unfortunately, it is possible for these chronic health conditions to increase the risk for dementia.

# %% [markdown]
# ### 3.4 -  Q: Is dementia more common in those with other chronic health conditions?

# %% [markdown]
# This question explores patients with and without dementia and what other chronic health conditions they suffer from including diabetes, hypertension, or heart disease.

# %%
#SQL statement to get table of dementia patients and underlying conditions
#use a case when then to ensure the null case is a category on the bar chart
#Code removed by Dr. R
# Out:
#   health_condition  num_health_condition
# 0         Diabetes                   260
# 1     No Condition                    88
# 2     Hypertension                    72
# 3    Heart Disease                    65

# %%
#SQL statement to get table of non-dementia patients and underlying conditions
#use a case when then to ensure the null case is a category on the bar chart
#Code removed by Dr. R
# Out:
#   health_condition  num_health_condition
# 0         Diabetes                   253
# 1     No Condition                    91
# 2    Heart Disease                    90
# 3     Hypertension                    81

# %%
# Graph code
#bar chart of underlying health conditions in dementia and nondementia patients
#Code removed by Dr. R

# %% [markdown]
# From this graph, we notice that the chronic health conditions represented in our data do not show much affect on whether a patient has dementia or not. For diabetes, hypertension, heart disease, and those with no chronic health conditions, the number of patients with and without dementia is relatively the same. Perhaps we see this trend because dementia is a syndrome associated with cognitive abilities ([What is Dementia](https://www.mayoclinic.org/diseases-conditions/dementia/symptoms-causes/syc-20352013)), and these chronic health conditions are not cognitive.

# %% [markdown]
# While dementia is sometimes unavoidable due to genetic risk factors, it is crucial to understand that there are medications to alleviate dementia symptoms ([Dementia - Diagnosis and Treatment](https://www.mayoclinic.org/diseases-conditions/dementia/diagnosis-treatment/drc-20352019)).

# %% [markdown]
# ### 3.5 -  Q: What are the most common medications in dementia patients?

# %% [markdown]
# This questions looks at the group of patients with dementia in the dataset and what medications are most common amongst them.

# %%
#SQL statement to get dementia patients medications
#Code removed by Dr. R
# Out:
#    prescription  num_medication
# 0     Memantine             128
# 1   Galantamine             125
# 2  Rivastigmine             119
# 3     Donepezil             113

# %%
# Graph code
#bar chart of medications in dementia and nondementia patients
#Code removed by Dr. R

# %% [markdown]
# From this visualization, we observe that the four medications prescribed to patients that have dementia in this study are Memantine, Galantamine, Rivastigmine, and Donepezil. The medications are are similarly common in the patients, however, the top three medications prescribed for the dementia patients are Memantine, Galantamine, and Rivastigmine. These medications work to manage symptoms, as there is no cure to dementia ([Dementia - Diagnosis and Treatment](https://www.mayoclinic.org/diseases-conditions/dementia/diagnosis-treatment/drc-20352019)).

# %% [markdown]
# After looking at the most common medications in dementia patients, it is important to recognize that not all medications will be given at the same dosage. Since dementia can be diagnosed from a variety of different ages, starting around age 65, the medication dosage could differ based on a patient's age.

# %% [markdown]
# ### 3.6 -  Q: Does the medication dosage of Memantine, Galantamine, and Rivastigmine differ across age?

# %% [markdown]
# This question looks at the average dosage of the top three medications prescribed to dementia patients across age.

# %%
#analyze patients on memantine
#Code removed by Dr. R
# Out:
#     age  avg_presc
# 0    60  10.000000
# 1    61  12.777778
# 2    62  13.750000
# 3    63  15.000000
# 4    64  10.000000
# 5    65  15.000000
# 6    66   6.250000
# 7    67  15.000000
# 8    68   6.666667
# 9    69  12.500000
# 10   70   7.500000
# 11   71  11.666667
# 12   72  11.250000
# 13   73  10.500000
# 14   74  11.000000
# 15   75  10.000000
# 16   76  13.750000
# 17   77  13.333333
# 18   78  16.666667
# 19   79   9.166667
# 20   80   5.000000
# 21   81  10.000000
# 22   82  11.666667
# 23   83  15.000000
# 24   84  11.666667
# 25   85   6.666667
# 26   86   7.500000
# 27   87  12.000000
# 28   88   8.750000
# 29   89   9.000000
# 30   90  10.000000

# %%
#analyze patients on galantamine
#Code removed by Dr. R
# Out:
#     age  avg_presc
# 0    60   7.111111
# 1    61  10.000000
# 2    62   7.333333
# 3    63  12.000000
# 4    64   4.000000
# 5    65   9.600000
# 6    66  10.666667
# 7    67   8.000000
# 8    68   8.000000
# 9    69   8.000000
# 10   70   4.000000
# 11   71   8.444444
# 12   72   8.000000
# 13   73   9.600000
# 14   74   6.666667
# 15   75   9.600000
# 16   76  12.000000
# 17   77   7.200000
# 18   78  10.000000
# 19   79   6.000000
# 20   80   6.000000
# 21   81   8.000000
# 22   82  12.000000
# 23   83   8.444444
# 24   84  12.000000
# 25   85   7.000000
# 26   86   8.000000
# 27   87   8.000000
# 28   88   7.333333
# 29   89   4.000000
# 30   90   4.000000

# %%
#analyze patients on rivastigmine
#Code removed by Dr. R
# Out:
#     age  avg_presc
# 0    60     4.1250
# 1    61     4.0000
# 2    62     4.2000
# 3    63     2.2500
# 4    64     2.2500
# 5    65     3.0000
# 6    66     4.5000
# 7    67     2.6250
# 8    68     4.0000
# 9    69     2.7000
# 10   70     3.9000
# 11   71     2.6250
# 12   72     4.0000
# 13   73     3.7500
# 14   74     3.0000
# 15   75     3.0000
# 16   76     3.0000
# 17   77     2.7000
# 18   78     3.0000
# 19   79     3.0000
# 20   80     4.5000
# 21   81     3.5000
# 22   82     3.2500
# 23   83     4.0000
# 24   84     5.0000
# 25   85     2.6250
# 26   86     6.0000
# 27   87     2.6250
# 28   88     4.5000
# 29   89     3.5000
# 30   90     3.1875

# %%
#average dosage of each medication
#Code removed by Dr. R
# Out:
#    prescription  avg_presc
# 0     Donepezil  14.212389
# 1   Galantamine   8.096000
# 2     Memantine  11.210938
# 3  Rivastigmine   3.491597

# %%
# Graph code
#line graph of the average medication dosage per age for dementia patients on memantine vs galantamine vs rivastigmine
#Code removed by Dr. R

# %% [markdown]
# From this graph, we see that age does not have much of a relationship with presecription dosage for different medications prescribed to the dementia patients. Overall, the graph is not increasing or decreasing in medication dosage as age increases. However, we can see that the different medications have different dosages in general. The average dosage of Memantine is 11.2 mg and the average dosage of Galantamine is 8.1 mg. Rivastigmine has an average dosage of 3.5 mg, much lower than the others. We visualize the differences of these average dosages on the graph, even though age does not have much affect on them.

# %% [markdown]
# Following the analysis of dementia risk factors, as well as treatments, it is important to look at the symptoms of dementia.

# %% [markdown]
# ### 3.7 -  Q: How does dementia affect cognitive score?

# %% [markdown]
# This question is meant to look at cognitive score between dementia patients and those without dementia. There are many different cognitive tests that exist to evaluate one's thinking ability, but this one measures ability on a scale of 1 to 10. It allows us to see if dementia has an effect on cognitive function, mesured through a cognitive test.

# %%
#SQL statement to select patients with dementia
#Code removed by Dr. R
# Out:
#      cognitive_score  dementia
# 0                  1         1
# 1                  5         1
# 2                  0         1
# 3                  1         1
# 4                  7         1
# ..               ...       ...
# 480                5         1
# 481                7         1
# 482                7         1
# 483                5         1
# 484                2         1
#
# [485 rows x 2 columns]

# %%
#SQL statement to select patients without dementia
#Code removed by Dr. R
# Out:
#      cognitive_score  dementia
# 0                 10         0
# 1                  8         0
# 2                  9         0
# 3                 10         0
# 4                  9         0
# ..               ...       ...
# 510                9         0
# 511                8         0
# 512                9         0
# 513                8         0
# 514               10         0
#
# [515 rows x 2 columns]

# %%
#SQL statement of avg cognitive score in dementia patients
#Code removed by Dr. R
# Out:
#    avg_score
# 0   3.620619

# %%
#SQL statement of avg cognitive score in dementia patients
#Code removed by Dr. R
# Out:
#    avg_score
# 0   8.984466

# %%
# Graph code
#2 histograms of cognitive score for patients with and without dementia
#Code removed by Dr. R

# %% [markdown]
# From this graph we can see that people in this study with dementia scored lower on the cognitive test than people without dementia. Out of the 1000 results that were taken, not one person with dementia scored above an 8, while no one without dementia scored below an 8. We also see that the average cognitive score of those with dementia is about 3.6, while the average cognitive score of those without dementia is about 9. This graph encourages the viewer to acknowledge that dementia could have a negative affect on cognitive function. We believe this is sensible since dementia is a syndrome associated with cognitive abilities such as attention, memory, and problem solving ([What is Dementia](https://www.cdc.gov/aging/dementia/index.html/)).

# %% [markdown]
# Now that we have looked at medication dosages and cognitive score in dementia patients, we will look at how the two correlate to each other.

# %% [markdown]
# ### 3.8 -  Q: Does a lower cognitive score correlate to a higher prescription dosage in dementia patients?

# %% [markdown]
# This question looks at the group of patients in the dataset that have been diagnosed with dementia. After looking at both cognitive score and prescription medication in dementia patients in previous visualizations, this question will explore if having a lower cognitive score is correlated to a higher prescription dosage.

# %%
#SQL statement to get table of cognitive score and prescription dosage in dementia patients
#Code removed by Dr. R
# Out:
#      cognitive_score  prescription_dosage
# 0                  1                 12.0
# 1                  5                 23.0
# 2                  0                 20.0
# 3                  1                  1.5
# 4                  7                 10.0
# ..               ...                  ...
# 480                5                 10.0
# 481                7                  1.5
# 482                7                 12.0
# 483                5                 10.0
# 484                2                 20.0
#
# [485 rows x 2 columns]

# %%
#Graph code
#scatter plot of cognitive score and prescription dosage
#Code removed by Dr. R

# %%
#correlation between cognitive score and prescription dosage in dementia patients
#Code removed by Dr. R
# Out:
# -0.048367468708163754

# %% [markdown]
# From this scatter plot, we can see that there is almost no linear correlation between cognitive score and prescription dosage, as the correlation coefficient is -0.048. This shows us that there is no linear relationship between cognitive score and prescription dosage. We believe this is sensible based on our previous visualization that showed us that different medications have different prescription dosages. Presciption dosages will be more dependent on what type of medication is being prescribed, rather than the cognitive score of the patient.

# %% [markdown]
# While cognitive score does not have any linear correlation with prescription dosage, perhaps there are other lifestyle aspects that have to do with cognition. For example, increasing stress levels can affect cognitive function in everyone ([Stress May Lead to Lower Cognitive Function](https://www.cnn.com/2023/03/07/health/high-stress-lower-cognition-study-wellness/index.html)), so it is important to look at increasing stress levels in dementia patients.

# %% [markdown]
# ### 3.9 -  Q: Do patients with dementia tend to have increasing stress levels?

# %% [markdown]
# For this question, we wanted to explore if patients with dementia have increasing stress levels. We wanted to ask this question as both dementia and stress affect cognitive abilities.

# %%
#SQL statement joining the dementia table and the mental health table on id
#SQL statement selecting growing stress levels of dementia patients
#Code removed by Dr. R
# Out:
#   Growing_Stress  num_patients
# 0            Yes           371
# 1             No           114

# %%
# Graph code
#bar chart of growing stress in dementia and patients
#Code removed by Dr. R

# %% [markdown]
# From this graph we can observe that patients diagnosed with
# dementia in this study tend to experience growing levels of stress. Perhaps this makes sense because stress may lead to lower cognitive function ([Stress May Lead to Lower Cognitive Function](https://www.cnn.com/2023/03/07/health/high-stress-lower-cognition-study-wellness/index.html)), and dementia patients tend to have lower cognitive function. Knowing that it is possible for stress to lead to lower cognitive function is important, as increasing stress levels of patients could be critical to their diagnosis of dementia. Based on this information, we believe that it could be possible for high stress levels throughout life to increase risk for dementia, as cognitive function will decline.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Throughout this project, many discoveries were made. First, there are some risk factors for dementia that can be controlled, such as sleep quality. We saw more cases of dementia in those with poor sleep quality, than those with good sleep quality. Additionally, there are risk factors of dementia that are unavoidable. For example, if a patient is born with the APOE ε4 allele, we found that they are more likely to have dementia. However, having the allele does not necessarily mean one will develop dementia. Another unavoidable risk factor of dementia we explored was aging. We found that dementia diagnosis is usually from ages 60 to 90, but it is most common from ages 60 to 65 and 85 to 95. Chronic health conditions can also act as a risk factor for dementia, however, our data did not show much correlation between the two. Many chronic health conditions had the same amount of dementia patients as non-dementia patients.
#
# After looking at some of the most common risk factors of dementia, we moved into treatments for demetia symptoms. In this case, we looked at medications. We first found that the four medications in our study prescribed to patients with dementia are Memantine, Galantamine, Rivastigmine, and Donepezil. Memantine was prescribed to the most amount of patients and Donepezil to the least amount of patients. After looking at the medications prescribed to dementia patients, we decided to look at the average dosage for the top three most common medicines across age. We found that age does not affect dosage very much. However, we did find that each medication have very different levels of dosage, no matter the age of the patient. Memantine requrires the highest dosage, then Galantamine, and then Rivastigmine.
#
# After exploring dementia risk factors and treatments, we decided to look at the main symptom of dementia, cognitive function. We knew from previous research that dementia affects cognitive abilities, but wanted to see how this reflected in our data. We found that those with dementia in our study did not score above an 8 on the cognitive test, while those without dementia in the study always scored above an 8 on the test. Next, we wanted to explore if the cognitive score of dementia patients had any linear correlation with the dosage of the prescription they are prescribed. We did not find any correlation between the two, perhaps because each medication is different. Finally we wanted to look at cognitive function and increasing stress levels. From previous research, we found that increasing stress levels can lower cognitive function. Because of this, we wanted to see if increasing stress levels play a part in dementia, as they both affect cognitive function. We affirmed our belief that increasing stress could play a part in dementia, as more dementia patients in our study experienced growing stress levels than not.
#
#
# Despite the insightful results we have discovered throughout this project, there are still other things we would like to explore.
#
# If we had more time in the future, we would have liked to explore all risk factors of dementia, rather than just the top risk factors. For example, we would have liked to explore how family history and depression plays a role in dementia, as well diet and alcohol abuse. Being able to analyze all the risk factors given in our dataset would have given a clearer depiction of what is most important to observe in patients. Also, exploring all the risk factors in our data would have allowed us to see if all risk factors are just as important as the most common ones.
#
# Additionally, if we could find the perfect data, we would have liked to have more numerical data. While we had some numerical variables that made for informative visuals, most of our data was categorical. If we had more numerical variables, we could have had more in depth visuals where we could compare using correlation coefficients and line graph trends. For example, if we were given our poor sleep vs. good sleep variable in a numerical way, such as ranking the quality of sleep on a scale from 1 to 10, we could have created a scatter plot of the quality of sleep vs. age in dementia patients to see if there is any linear correlation.
